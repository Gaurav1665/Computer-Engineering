# %% [markdown]
# <a href='https://www.darshan.ac.in/'><img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="85"/></a><pre><center><table>
#             <tr>
#                 <th><h1> &nbsp;&nbsp;&nbsp;&nbsp;Data Mining</h1></th>
#                 <th><h1>:</h1></th>
#                 <th><h1>Task - 1 &nbsp;&nbsp;&nbsp;&nbsp;</h1></th>
#             </tr>
#             <tr>
#                 <th><h1> &nbsp;&nbsp;&nbsp;&nbsp; Name</h1></th>
#                 <th><h1>:</h1></th>
#                 <th><h1>Ida Gaurav R. &nbsp;&nbsp;&nbsp;&nbsp; </h1></th>
#             </tr>
#             <tr>
#                 <th><h1> &nbsp;&nbsp;&nbsp;&nbsp; Enrollment no</h1></th>
#                 <th><h1>:</h1></th>
#                 <th><h1>24010101637 &nbsp;&nbsp;&nbsp;&nbsp; </h1></th>
#             </tr>
#             <tr>
#                 <th><h1> &nbsp;&nbsp;&nbsp;&nbsp; Roll no</h1></th>
#                 <th><h1>:</h1></th>
#                 <th><h1>354 &nbsp;&nbsp;&nbsp;&nbsp; </h1></th>
#             </tr></table></center><pre>

# %% [markdown]
# # 📦 Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 🧪 Load the dataset

# %%
df = pd.read_csv('OnlineRetail.csv', encoding='ISO-8859-1')

# %% [markdown]
# # -------------------------------------
# # ✅ PANDAS - DATA EXPLORATION (25 methods)
# # -------------------------------------

# %%
df.head(5) # View top 5 rows
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(df.info())  # Structure & datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None

# %%
print(df.describe())  # Descriptive stats
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print("\n🔹 Column names:")
print(df.columns)
# Out:
# 🔹 Column names:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
print("\n🔹 Shape of dataset:")
print(df.shape)
# Out:
# 🔹 Shape of dataset:
# (541909, 8)

# %%
print("\n🔹 Data types:")
print(df.dtypes)
# Out:
# 🔹 Data types:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
print("\n🔹 Null values in each column:")
print(df.isnull().sum())
# Out:
# 🔹 Null values in each column:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print("\n🔹 Fill null values with 0:")
print(df.fillna(0).head())
# Out:
# 🔹 Fill null values with 0:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print("\n🔹 Drop rows with null values:")
print(df.dropna().head())
# Out:
# 🔹 Drop rows with null values:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print("\n🔹 Rename column (if needed):")
print(df.rename(columns={df.columns[0]: 'Renamed_Column'}).head())
# Out:
# 🔹 Rename column (if needed):
#   Renamed_Column StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print("\n🔹 Drop a column:")
print(df.drop(columns=df.columns[-1]).head())
# Out:
# 🔹 Drop a column:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID
# 0  12/1/2010 8:26       2.55     17850.0
# 1  12/1/2010 8:26       3.39     17850.0
# 2  12/1/2010 8:26       2.75     17850.0
# 3  12/1/2010 8:26       3.39     17850.0
# 4  12/1/2010 8:26       3.39     17850.0

# %%
print("\n🔹 Sort by a column:")
print(df.sort_values(by=df.columns[1]).head())
# Out:
# 🔹 Sort by a column:
#        InvoiceNo StockCode                  Description  Quantity  \
# 160128    550452     10002  INFLATABLE POLITICAL GLOBE          1
# 6166      536876     10002  INFLATABLE POLITICAL GLOBE          2
# 75792     542610     10002  INFLATABLE POLITICAL GLOBE         14
# 63082     541518     10002  INFLATABLE POLITICAL GLOBE         12
# 76571     542629     10002  INFLATABLE POLITICAL GLOBE        120
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 160128  4/18/2011 12:56       0.85     14525.0  United Kingdom
# 6166    12/3/2010 11:36       1.66         NaN  United Kingdom
# 75792   1/30/2011 14:05       0.85     13148.0  United Kingdom
# 63082    1/19/2011 9:05       0.85     12451.0     Switzerland
# 76571    1/31/2011 9:57       0.85     12731.0          France

# %%
print("\n🔹 Filter rows where numeric column > 50:")
print(df[df.select_dtypes(include='number').columns[0]] > 50)
# Out:
# 🔹 Filter rows where numeric column > 50:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: Quantity, Length: 541909, dtype: bool

# %%
print("\n🔹 Group by first column, mean of second:")
print(df.groupby(df.columns[0])[df.columns[3]].mean())
# Out:
# 🔹 Group by first column, mean of second:
# InvoiceNo
# 536365         5.714286
# 536366         6.000000
# 536367         6.916667
# 536368         3.750000
# 536369         3.000000
#                ...
# C581484   -80995.000000
# C581490      -11.500000
# C581499       -1.000000
# C581568       -5.000000
# C581569       -3.000000
# Name: Quantity, Length: 25900, dtype: float64

# %%
print("\n🔹 Value counts of a column:")
print(df[df.columns[0]].value_counts())
# Out:
# 🔹 Value counts of a column:
# InvoiceNo
# 573585     1114
# 581219      749
# 581492      731
# 580729      721
# 558475      705
#            ...
# 554023        1
# 554022        1
# 554021        1
# 554020        1
# C558901       1
# Name: count, Length: 25900, dtype: int64

# %%
print("\n🔹 Count duplicates:")
print(df.duplicated().sum())
# Out:
# 🔹 Count duplicates:
# 5268

# %%
print("\n🔹 Correlation matrix:")
print(df.select_dtypes(include='number').corr())
# Out:
# 🔹 Correlation matrix:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
print("\n🔹 Correlation matrix:")
df.cov(numeric_only = "true")
# Out:
# 🔹 Correlation matrix:
#                 Quantity    UnitPrice    CustomerID
# Quantity    47559.391409   -26.058761 -1.534050e+03
# UnitPrice     -26.058761  9362.469164 -5.415793e+02
# CustomerID  -1534.050176  -541.579276  2.936426e+06

# %%
print("\n🔹 Unique values:")
print(df[df.columns[0]].unique())
# Out:
# 🔹 Unique values:
# ['536365' '536366' '536367' ... '581585' '581586' '581587']

# %%
print("\n🔹 Number of unique values:")
print(df[df.columns[0]].nunique())
# Out:
# 🔹 Number of unique values:
# 25900

# %%
print("\n🔹 Random 5 samples:")
print(df.sample(5))
# Out:
# 🔹 Random 5 samples:
#        InvoiceNo StockCode                       Description  Quantity  \
# 521145    580317     22470             HEART OF WICKER LARGE        12
# 408493    571941     23553       LANDMARK FRAME CAMDEN TOWN          3
# 539363    581439    90200A        PURPLE SWEETHEART BRACELET         1
# 7268      537025     90145  SILVER HOOP EARRINGS WITH FLOWER         1
# 338543    566560     23241      TREASURE TIN GYMKHANA DESIGN         4
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 521145   12/2/2011 15:29       2.95     13458.0  United Kingdom
# 408493  10/20/2011 10:04      12.50     14261.0  United Kingdom
# 539363   12/8/2011 16:30       4.15         NaN  United Kingdom
# 7268     12/3/2010 16:21       5.95         NaN  United Kingdom
# 338543   9/13/2011 12:09       2.08     17092.0  United Kingdom

# %%
print("\n🔹 Set index to first column:")
print(df.set_index(df.columns[0]).head())
# Out:
# 🔹 Set index to first column:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 536365       85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 536365        71053                  WHITE METAL LANTERN         6
# 536365       84406B       CREAM CUPID HEARTS COAT HANGER         8
# 536365       84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 536365       84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# InvoiceNo
# 536365     12/1/2010 8:26       2.55     17850.0  United Kingdom
# 536365     12/1/2010 8:26       3.39     17850.0  United Kingdom
# 536365     12/1/2010 8:26       2.75     17850.0  United Kingdom
# 536365     12/1/2010 8:26       3.39     17850.0  United Kingdom
# 536365     12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print("\n🔹 Reset index:")
print(df.reset_index().head())
# Out:
# 🔹 Reset index:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print("\n🔹 Apply lambda to double a column:")
print(df[df.select_dtypes(include='number').columns[0]].apply(lambda x: x * 2).head())
# Out:
# 🔹 Apply lambda to double a column:
# 0    12
# 1    12
# 2    16
# 3    12
# 4    12
# Name: Quantity, dtype: int64

# %%
print("\n🔹 Concatenate df to itself:")
print(pd.concat([df, df]).head())
# Out:
# 🔹 Concatenate df to itself:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # -------------------------------------
# # 🔢 NUMPY - NUMERICAL ANALYSIS (25 methods)
# # -------------------------------------

# %%
arr = df.select_dtypes(include='number').to_numpy()

# %%
print("\n🔹 NumPy Mean:", np.mean(arr, axis=0))
# Out:
# 🔹 NumPy Mean: [9.55224955 4.61111363        nan]

# %%
print("🔹 NumPy Median:", np.median(arr, axis=0))
# Out:
# 🔹 NumPy Median: [3.   2.08  nan]

# %%
print("🔹 Std Dev:", np.std(arr, axis=0))
# Out:
# 🔹 Std Dev: [218.08095663  96.75976378          nan]

# %%
print("🔹 Variance:", np.var(arr, axis=0))
# Out:
# 🔹 Variance: [47559.30364661  9362.45188759            nan]

# %%
print("🔹 Min:", np.min(arr, axis=0))
# Out:
# 🔹 Min: [-80995.   -11062.06       nan]

# %%
print("🔹 Max:", np.max(arr, axis=0))
# Out:
# 🔹 Max: [80995. 38970.    nan]

# %%
print("🔹 Sum:", np.sum(arr, axis=0))
# Out:
# 🔹 Sum: [5176450.    2498803.974         nan]

# %%
print("🔹 Cumulative Sum:", np.cumsum(arr, axis=0))
# Out:
# 🔹 Cumulative Sum: [[6.00000000e+00 2.55000000e+00 1.78500000e+04]
#  [1.20000000e+01 5.94000000e+00 3.57000000e+04]
#  [2.00000000e+01 8.69000000e+00 5.35500000e+04]
#  ...
#  [5.17644300e+06 2.49879487e+06            nan]
#  [5.17644700e+06 2.49879902e+06            nan]
#  [5.17645000e+06 2.49880397e+06            nan]]

# %%
print("🔹 Difference between rows:", np.diff(arr, axis=0))
# Out:
# 🔹 Difference between rows: [[ 0.    0.84  0.  ]
#  [ 2.   -0.64  0.  ]
#  [-2.    0.64  0.  ]
#  ...
#  [-2.    2.05  0.  ]
#  [ 0.    0.    0.  ]
#  [-1.    0.8   0.  ]]

# %%
print("🔹 Sorted array:", np.sort(arr, axis=0))
# Out:
# 🔹 Sorted array: [[-80995.   -11062.06  12346.  ]
#  [-74215.   -11062.06  12346.  ]
#  [ -9600.        0.    12347.  ]
#  ...
#  [ 12540.    16888.02       nan]
#  [ 74215.    17836.46       nan]
#  [ 80995.    38970.         nan]]

# %%
print("\n🔹 Condition: values > 50:", np.where(arr[:, 0] > 50))
# Out:
# 🔹 Condition: values > 50: (array([    46,     83,     96, ..., 541711, 541746, 541867], dtype=int64),)

# %%
print("🔹 Unique values in column 0:", np.unique(arr[:, 0]))
# Out:
# 🔹 Unique values in column 0: [-8.0995e+04 -7.4215e+04 -9.6000e+03 -9.3600e+03 -9.0580e+03 -5.3680e+03
#  -4.8300e+03 -3.6670e+03 -3.1670e+03 -3.1140e+03 -3.1000e+03 -3.0000e+03
#  -2.8800e+03 -2.8340e+03 -2.6180e+03 -2.6000e+03 -2.4720e+03 -2.3760e+03
#  -2.0030e+03 -2.0000e+03 -1.9300e+03 -1.8970e+03 -1.6810e+03 -1.6710e+03
#  -1.5600e+03 -1.5150e+03 -1.5120e+03 -1.5100e+03 -1.4790e+03 -1.4400e+03
#  -1.4300e+03 -1.4000e+03 -1.3500e+03 -1.3000e+03 -1.2960e+03 -1.2840e+03
#  -1.2770e+03 -1.2060e+03 -1.2000e+03 -1.1580e+03 -1.1310e+03 -1.1280e+03
#  -1.1210e+03 -1.1000e+03 -1.0920e+03 -1.0600e+03 -1.0500e+03 -1.0000e+03
#  -9.9000e+02 -9.7500e+02 -9.6700e+02 -9.6000e+02 -9.3900e+02 -9.0500e+02
#  -9.0000e+02 -8.6400e+02 -8.4000e+02 -8.2800e+02 -8.0000e+02 -7.8600e+02
#  -7.5600e+02 -7.5200e+02 -7.5000e+02 -7.4100e+02 -7.2300e+02 -7.2000e+02
#  -7.0100e+02 -6.9600e+02 -6.9000e+02 -6.8200e+02 -6.7500e+02 -6.7400e+02
# ...

# %%
print("\n🔹 Random float matrix:")
print(np.random.rand(3, 3))
# Out:
# 🔹 Random float matrix:
# [[0.47441492 0.15257059 0.95902913]
#  [0.24275327 0.2761828  0.86412452]
#  [0.27490351 0.15632038 0.13273008]]

# %%
print("\n🔹 Random int matrix:")
print(np.random.randint(0, 100, (3, 3)))
# Out:
# 🔹 Random int matrix:
# [[45  0  0]
#  [87 44 41]
#  [77 32 56]]

# %%
print("\n🔹 Zeros matrix:")
print(np.zeros((2, 2)))
# Out:
# 🔹 Zeros matrix:
# [[0. 0.]
#  [0. 0.]]

# %%
print("\n🔹 Ones matrix:")
print(np.ones((2, 2)))
# Out:
# 🔹 Ones matrix:
# [[1. 1.]
#  [1. 1.]]

# %%
print("\n🔹 Dot product of matrix:")
print(np.dot(arr.T, arr))
# Out:
# 🔹 Dot product of matrix:
# [[2.58222614e+10 9.74774793e+06            nan]
#  [9.74774793e+06 5.08511921e+09            nan]
#  [           nan            nan            nan]]

# %%
print("\n🔹 Reshaped array:")
print(np.reshape(arr, (-1, arr.shape[1])))
# Out:
# 🔹 Reshaped array:
# [[6.000e+00 2.550e+00 1.785e+04]
#  [6.000e+00 3.390e+00 1.785e+04]
#  [8.000e+00 2.750e+00 1.785e+04]
#  ...
#  [4.000e+00 4.150e+00 1.268e+04]
#  [4.000e+00 4.150e+00 1.268e+04]
#  [3.000e+00 4.950e+00 1.268e+04]]

# %%
print("\n🔹 Transpose:")
print(np.transpose(arr))
# Out:
# 🔹 Transpose:
# [[6.000e+00 6.000e+00 8.000e+00 ... 4.000e+00 4.000e+00 3.000e+00]
#  [2.550e+00 3.390e+00 2.750e+00 ... 4.150e+00 4.150e+00 4.950e+00]
#  [1.785e+04 1.785e+04 1.785e+04 ... 1.268e+04 1.268e+04 1.268e+04]]

# %%
print("\n🔹 Indices that would sort column 0:")
print(np.argsort(arr[:, 0]))
# Out:
# 🔹 Indices that would sort column 0:
# [540422  61624 225529 ... 502122  61619 540421]

# %%
print("\n🔹 Clipped values (0 to 100):")
print(np.clip(arr, 0, 100))
# Out:
# 🔹 Clipped values (0 to 100):
# [[  6.     2.55 100.  ]
#  [  6.     3.39 100.  ]
#  [  8.     2.75 100.  ]
#  ...
#  [  4.     4.15 100.  ]
#  [  4.     4.15 100.  ]
#  [  3.     4.95 100.  ]]

# %%
print("🔹 Square root (only non-negative):")
print(np.sqrt(np.clip(arr, a_min=0, a_max=None)))
# Out:
# 🔹 Square root (only non-negative):
# [[  2.44948974   1.59687194 133.60389216]
#  [  2.44948974   1.84119526 133.60389216]
#  [  2.82842712   1.6583124  133.60389216]
#  ...
#  [  2.           2.03715488 112.60550608]
#  [  2.           2.03715488 112.60550608]
#  [  1.73205081   2.22485955 112.60550608]]

# %%
clipped_arr = np.clip(arr, a_min=None, a_max=100)  # cap values to prevent overflow
print("🔹 Exponential (capped):")
print(np.exp(clipped_arr))
# Out:
# 🔹 Exponential (capped):
# [[4.03428793e+02 1.28071038e+01 2.68811714e+43]
#  [4.03428793e+02 2.96659523e+01 2.68811714e+43]
#  [2.98095799e+03 1.56426319e+01 2.68811714e+43]
#  ...
#  [5.45981500e+01 6.34340003e+01 2.68811714e+43]
#  [5.45981500e+01 6.34340003e+01 2.68811714e+43]
#  [2.00855369e+01 1.41174964e+02 2.68811714e+43]]

# %%
safe_arr = np.where(arr > 0, arr, np.nan)
print("🔹 Log of positive values:")
print(np.log(safe_arr))
# Out:
# 🔹 Log of positive values:
# [[1.79175947 0.93609336 9.78975879]
#  [1.79175947 1.22082992 9.78975879]
#  [2.07944154 1.01160091 9.78975879]
#  ...
#  [1.38629436 1.42310833 9.44778123]
#  [1.38629436 1.42310833 9.44778123]
#  [1.09861229 1.59938758 9.44778123]]

# %%
print("\n🔹 Check NaN values:")
print(np.isnan(arr))
# Out:
# 🔹 Check NaN values:
# [[False False False]
#  [False False False]
#  [False False False]
#  ...
#  [False False False]
#  [False False False]
#  [False False False]]

# %% [markdown]
# # -------------------------------------
# # 📊 MATPLOTLIB - VISUALIZATION (25 methods)
# # -------------------------------------

# %% [markdown]
# ## line plot

# %%
col1 = df.select_dtypes(include='number').columns[0]
col2 = df.select_dtypes(include='number').columns[1] if df.shape[1] > 1 else col1

plt.figure(figsize=(10, 4))
plt.plot(df[col1], label='Line')
plt.title("Line Plot")
plt.xlabel(col1)
plt.ylabel("Values")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.hist(df[col1], bins=20, color='skyblue')
plt.title("Histogram of " + col1)
plt.xlabel(col1)
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter

# %%
plt.scatter(df[col1], df[col2], c='red')
plt.title("Scatter Plot")
plt.xlabel(col1)
plt.ylabel(col2)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bar chart (if categorical)

# %%
if df[col1].nunique() <= 20:
    df[col1].value_counts().plot(kind='bar', color='orange')
    plt.title("Bar Chart of " + col1)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(df[col1])
plt.title("Boxplot of " + col1)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Pie chart (if categorical)

# %%
if df[col1].nunique() <= 6:
    df[col1].value_counts().plot.pie(autopct='%1.1f%%')
    plt.title("Pie Chart")
    plt.ylabel("")
    plt.tight_layout()
    plt.show()
